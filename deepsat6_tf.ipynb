# %%
import tensorflow as tf
# Out:
# /home/worker3/utils/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import numpy as np
import pandas as pd
#import pickle

x_train = pd.read_csv(tf.gfile.Open('data/X_train_sat6.csv'),header=None) #This will kill the available memory on the kaggle machine :\
y_train = pd.read_csv(tf.gfile.Open('data/y_train_sat6.csv'),header=None)
x_train = x_train.values.reshape(x_train.shape[0],28,28,4).astype(np.float32)
y_train = y_train.values.astype(np.float32)

x_eval = pd.read_csv(tf.gfile.Open('data/X_test_sat6.csv'),header=None)
y_eval = pd.read_csv(tf.gfile.Open('data/y_test_sat6.csv'),header=None)
x_eval = x_eval.values.reshape(x_eval.shape[0],28,28,4).astype(np.float32)
y_eval = y_eval.values.astype(np.float32)

print("All files loaded")
# Out:
# All files loaded

# %%
def model_fn(features, labels, mode, params, config):

    # Input Layer
    input_layer = tf.reshape(features["x"], [-1,28,28,4])
    tf.summary.image('input_layer',input_layer)

    # First Convolutional Layer
    conv1 = tf.layers.conv2d(inputs=input_layer,
                               filters=32,
                               kernel_size=[5,5],
                               padding='same',
                               activation=tf.nn.relu)

    print("Shape Conv1:" + str(conv1.shape))

    # First MaxPool Layer
    pool1 = tf.layers.max_pooling2d(inputs=conv1, 
                                      pool_size=[2,2], 
                                      strides=2)
    print("Shape Pool1:" + str(pool1.shape))

    # Second Convolutional Layer
    conv2 = tf.layers.conv2d(inputs=pool1,
                               filters=64,
                               kernel_size=[5,5],
                               padding='same',
                               activation=tf.nn.relu)
    print("Shape Conv2:" + str(conv2.shape))

    # Second MaxPool Layer
    pool2 = tf.layers.max_pooling2d(inputs=conv2, 
                                      pool_size=[2, 2],
                                      strides=2)
    print("Shape Pool2:" + str(pool2.shape))

    # Flatten Pool2
    pool2_flat = tf.reshape(pool2, [-1, pool2.shape[1]*pool2.shape[2]*pool2.shape[3]])

    # First Dense Layer
    dense1 = tf.layers.dense(inputs=pool2_flat,
                              units=1024,
                              activation=tf.nn.relu)

    # Dropout Layer for Training
    dropout = tf.layers.dropout(inputs=dense1,
                                  rate=0.5,
                                  training=mode == tf.estimator.ModeKeys.TRAIN)

    # Second Dense Layer
    dense2 = tf.layers.dense(inputs=dropout,
                              units=256,
                              activation=tf.nn.relu)

    # Output Layer
    logits = tf.layers.dense(inputs=dense2, units=labels.shape[1])

    predictions = {
      "classes": tf.argmax(input=logits, axis=1), #Result Classes
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor") #Class Probabilities
    }

    # Predict Mode
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

    # Loss Function
    loss = tf.losses.softmax_cross_entropy(onehot_labels=labels,
                                             logits=logits)

    ## Classification Metrics
    # accuracy
    acc = tf.metrics.accuracy(labels=tf.argmax(labels,1),
                              predictions=predictions['classes'])

    # Precision
    prec = tf.metrics.precision(labels=tf.argmax(labels,1),
                                predictions=predictions['classes'])

    # Recall
    rec = tf.metrics.recall(labels=tf.argmax(labels,1),
                            predictions=predictions['classes'])

    # F1 Score
    f1 = 2 * acc[1] * rec[1] / ( prec[1] + rec[1] ) #misssing op -> too lazy to create ;)

    #TensorBoard Summary
    tf.summary.scalar('Accuracy', acc[1])
    tf.summary.scalar('Precision', prec[1])
    tf.summary.scalar('Recall', rec[1])
    tf.summary.scalar('F1Score', f1)
    tf.summary.histogram('Probabilities', predictions['probabilities'])
    tf.summary.histogram('Classes', predictions['classes'])

    summary_hook = tf.train.SummarySaverHook(summary_op=tf.summary.merge_all(),
                                             save_steps=1)

    # Learning Rate Decay (Exponential)
    learning_rate = tf.train.exponential_decay(learning_rate=1e-04,
                                               global_step=tf.train.get_global_step(),
                                               decay_steps=10000, 
                                               decay_rate=0.96, 
                                               staircase=True,
                                               name='lr_exp_decay')


    # Training Mode (Adam Optimizer)
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(loss=loss,
                                      global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, 
                                          loss=loss, 
                                          train_op=train_op)
                                          #training_hooks=[summary_hook])

    # Evaluation Metrics
    eval_metric_ops = {
        "Accuracy": acc,
        "Precision": prec,
        "Recall": rec,
    }

    # Evaluation Mode
    return tf.estimator.EstimatorSpec(mode=mode, 
                                      loss=loss, 
                                      eval_metric_ops=eval_metric_ops)

# %%
# Create Custom Classifier
sat6_classifier = tf.estimator.Estimator(model_fn=model_fn,
                                         model_dir='/home/worker3/projects/deepsat6/model',
                                         config=tf.estimator.RunConfig(save_summary_steps=1))

# This will create a lot of output ;)
# tensors_to_log = {"probabilities": "softmax_tensor"}
# logging_hook = tf.train.LoggingTensorHook(tensors=tensors_to_log, 
#                                          every_n_iter=1)

# Training input function
train_input_fn = tf.estimator.inputs.numpy_input_fn(x={"x": x_train},
                                                    y=y_train,
                                                    batch_size=512,
                                                    num_epochs=1,
                                                    shuffle=True)
# Evaluation input function
eval_input_fn = tf.estimator.inputs.numpy_input_fn(x={"x": x_eval},
                                                       y=y_eval,
                                                       num_epochs=1,
                                                       shuffle=False)

# 10 Training Epochs,  Evaluation Step after each Epoch
for i in range(10):
    print(f'Epoch {i+1}')
    sat6_classifier.train(input_fn=train_input_fn,)
#                             hooks=[logging_hook])
    eval_results = sat6_classifier.evaluate(input_fn=eval_input_fn)

#INFO:tensorflow:Loss for final step: 0.01437158.
#INFO:tensorflow:Calling model_fn.
#Shape Conv1:(?, 28, 28, 32)
#Shape Pool1:(?, 14, 14, 32)
#Shape Conv2:(?, 14, 14, 64)
#Shape Pool2:(?, 7, 7, 64)
#INFO:tensorflow:Done calling model_fn.
#INFO:tensorflow:Starting evaluation at 2018-03-11-14:09:55
#INFO:tensorflow:Graph was finalized.
#INFO:tensorflow:Restoring parameters from /tmp/cnn_model/model.ckpt-6330
#INFO:tensorflow:Running local_init_op.
#INFO:tensorflow:Done running local_init_op.
#INFO:tensorflow:Finished evaluation at 2018-03-11-14:11:19
#INFO:tensorflow:Saving dict for global step 6330: Accuracy = 0.98949385, Precision = 0.99994814, Recall = 0.9983826, global_step = 6330, loss = 0.030443478
#F1 Score = 0,98951163
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '/home/worker3/projects/deepsat6/model', '_tf_random_seed': None, '_save_summary_steps': 1, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fd7c2b04978>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x7fd7c2b99510>) includes params argument, but params are not passed to Estimator.
# Epoch 1
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-12661
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 12662 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:loss = 0.025922878, step = 12661
# INFO:tensorflow:global_step/sec: 22.4732
# INFO:tensorflow:loss = 0.023494592, step = 12761 (4.451 sec)
# INFO:tensorflow:global_step/sec: 24.2147
# INFO:tensorflow:loss = 0.01749384, step = 12861 (4.130 sec)
# INFO:tensorflow:global_step/sec: 24.1693
# INFO:tensorflow:loss = 0.02429982, step = 12961 (4.137 sec)
# INFO:tensorflow:global_step/sec: 24.0104
# INFO:tensorflow:loss = 0.0122419875, step = 13061 (4.166 sec)
# INFO:tensorflow:global_step/sec: 24.0204
# INFO:tensorflow:loss = 0.013965457, step = 13161 (4.164 sec)
# INFO:tensorflow:global_step/sec: 24.0344
# INFO:tensorflow:loss = 0.010121489, step = 13261 (4.159 sec)
# INFO:tensorflow:Saving checkpoints for 13294 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.011794316.
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-02-03:16:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-13294
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-02-03:16:23
# INFO:tensorflow:Saving dict for global step 13294: Accuracy = 0.9884321, Precision = 0.9995601, Recall = 0.9996765, global_step = 13294, loss = 0.029743586
# Epoch 2
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-13294
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13295 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:loss = 0.017779151, step = 13294
# INFO:tensorflow:global_step/sec: 22.7085
# INFO:tensorflow:loss = 0.018227436, step = 13394 (4.405 sec)
# INFO:tensorflow:global_step/sec: 24.0746
# INFO:tensorflow:loss = 0.020679597, step = 13494 (4.156 sec)
# INFO:tensorflow:global_step/sec: 23.9921
# INFO:tensorflow:loss = 0.031429667, step = 13594 (4.168 sec)
# INFO:tensorflow:global_step/sec: 23.9657
# INFO:tensorflow:loss = 0.011539755, step = 13694 (4.173 sec)
# INFO:tensorflow:global_step/sec: 24.0659
# INFO:tensorflow:loss = 0.024019571, step = 13794 (4.155 sec)
# INFO:tensorflow:global_step/sec: 23.953
# INFO:tensorflow:loss = 0.012773877, step = 13894 (4.173 sec)
# INFO:tensorflow:Saving checkpoints for 13927 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0064862785.
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-02-03:16:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-13927
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-02-03:16:58
# INFO:tensorflow:Saving dict for global step 13927: Accuracy = 0.99374074, Precision = 0.99965066, Recall = 0.9997412, global_step = 13927, loss = 0.019169174
# Epoch 3
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-13927
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13928 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:loss = 0.014506515, step = 13927
# INFO:tensorflow:global_step/sec: 22.0823
# INFO:tensorflow:loss = 0.009267467, step = 14027 (4.530 sec)
# INFO:tensorflow:global_step/sec: 23.8763
# INFO:tensorflow:loss = 0.020507863, step = 14127 (4.188 sec)
# INFO:tensorflow:global_step/sec: 23.9719
# INFO:tensorflow:loss = 0.018204363, step = 14227 (4.172 sec)
# INFO:tensorflow:global_step/sec: 23.8234
# INFO:tensorflow:loss = 0.025900276, step = 14327 (4.197 sec)
# INFO:tensorflow:global_step/sec: 23.944
# INFO:tensorflow:loss = 0.011653328, step = 14427 (4.177 sec)
# INFO:tensorflow:global_step/sec: 23.8403
# INFO:tensorflow:loss = 0.009019249, step = 14527 (4.194 sec)
# INFO:tensorflow:Saving checkpoints for 14560 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.015940178.
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-02-03:17:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-14560
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-02-03:17:33
# INFO:tensorflow:Saving dict for global step 14560: Accuracy = 0.9929506, Precision = 0.999599, Recall = 0.999793, global_step = 14560, loss = 0.021769062
# Epoch 4
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-14560
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 14561 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:loss = 0.005999899, step = 14560
# INFO:tensorflow:global_step/sec: 22.4827
# INFO:tensorflow:loss = 0.006111963, step = 14660 (4.451 sec)
# INFO:tensorflow:global_step/sec: 23.7755
# INFO:tensorflow:loss = 0.007971305, step = 14760 (4.204 sec)
# INFO:tensorflow:global_step/sec: 23.8563
# INFO:tensorflow:loss = 0.030351084, step = 14860 (4.192 sec)
# INFO:tensorflow:global_step/sec: 23.9225
# INFO:tensorflow:loss = 0.008343704, step = 14960 (4.180 sec)
# INFO:tensorflow:global_step/sec: 23.7759
# INFO:tensorflow:loss = 0.010562495, step = 15060 (4.208 sec)
# INFO:tensorflow:global_step/sec: 23.7449
# INFO:tensorflow:loss = 0.01477372, step = 15160 (4.210 sec)
# INFO:tensorflow:Saving checkpoints for 15193 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.004815322.
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-02-03:18:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-15193
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-02-03:18:09
# INFO:tensorflow:Saving dict for global step 15193: Accuracy = 0.99355555, Precision = 0.9998188, Recall = 0.99961185, global_step = 15193, loss = 0.01920582
# Epoch 5
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-15193
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 15194 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:loss = 0.009011973, step = 15193
# INFO:tensorflow:global_step/sec: 21.7463
# INFO:tensorflow:loss = 0.012868758, step = 15293 (4.600 sec)
# INFO:tensorflow:global_step/sec: 23.9048
# INFO:tensorflow:loss = 0.0065545854, step = 15393 (4.184 sec)
# INFO:tensorflow:global_step/sec: 23.849
# INFO:tensorflow:loss = 0.014620314, step = 15493 (4.192 sec)
# INFO:tensorflow:global_step/sec: 23.8237
# INFO:tensorflow:loss = 0.010026728, step = 15593 (4.198 sec)
# INFO:tensorflow:global_step/sec: 23.7953
# INFO:tensorflow:loss = 0.024925336, step = 15693 (4.202 sec)
# INFO:tensorflow:global_step/sec: 23.7905
# INFO:tensorflow:loss = 0.008594651, step = 15793 (4.204 sec)
# INFO:tensorflow:Saving checkpoints for 15826 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.011933868.
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-02-03:18:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-15826
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-02-03:18:44
# INFO:tensorflow:Saving dict for global step 15826: Accuracy = 0.9911482, Precision = 0.99988335, Recall = 0.9981109, global_step = 15826, loss = 0.026951667
# Epoch 6
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-15826
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 15827 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:loss = 0.020175591, step = 15826
# INFO:tensorflow:global_step/sec: 22.4592
# INFO:tensorflow:loss = 0.004987475, step = 15926 (4.454 sec)
# INFO:tensorflow:global_step/sec: 23.8245
# INFO:tensorflow:loss = 0.016888358, step = 16026 (4.198 sec)
# INFO:tensorflow:global_step/sec: 23.819
# INFO:tensorflow:loss = 0.013008153, step = 16126 (4.198 sec)
# INFO:tensorflow:global_step/sec: 23.5402
# INFO:tensorflow:loss = 0.009068448, step = 16226 (4.247 sec)
# INFO:tensorflow:global_step/sec: 23.7963
# INFO:tensorflow:loss = 0.00888048, step = 16326 (4.202 sec)
# INFO:tensorflow:global_step/sec: 23.7551
# INFO:tensorflow:loss = 0.024139743, step = 16426 (4.210 sec)
# INFO:tensorflow:Saving checkpoints for 16459 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.018967759.
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-02-03:19:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-16459
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-02-03:19:19
# INFO:tensorflow:Saving dict for global step 16459: Accuracy = 0.9932839, Precision = 0.9996766, Recall = 0.99978006, global_step = 16459, loss = 0.020927329
# Epoch 7
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-16459
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 16460 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:loss = 0.00941924, step = 16459
# INFO:tensorflow:global_step/sec: 22.0203
# INFO:tensorflow:loss = 0.01073139, step = 16559 (4.543 sec)
# INFO:tensorflow:global_step/sec: 23.9114
# INFO:tensorflow:loss = 0.0031358132, step = 16659 (4.182 sec)
# INFO:tensorflow:global_step/sec: 23.7425
# INFO:tensorflow:loss = 0.014078659, step = 16759 (4.212 sec)
# INFO:tensorflow:global_step/sec: 23.7936
# INFO:tensorflow:loss = 0.01429548, step = 16859 (4.203 sec)
# INFO:tensorflow:global_step/sec: 23.7197
# INFO:tensorflow:loss = 0.015297227, step = 16959 (4.217 sec)
# INFO:tensorflow:global_step/sec: 23.5791
# INFO:tensorflow:loss = 0.007445207, step = 17059 (4.240 sec)
# INFO:tensorflow:Saving checkpoints for 17092 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0033483787.
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-02-03:19:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-17092
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-02-03:19:55
# INFO:tensorflow:Saving dict for global step 17092: Accuracy = 0.9941852, Precision = 0.99993527, Recall = 0.9995342, global_step = 17092, loss = 0.019081978
# Epoch 8
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-17092
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 17093 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:loss = 0.00233112, step = 17092
# INFO:tensorflow:global_step/sec: 22.4572
# INFO:tensorflow:loss = 0.0024764228, step = 17192 (4.454 sec)
# INFO:tensorflow:global_step/sec: 23.6999
# INFO:tensorflow:loss = 0.010017261, step = 17292 (4.219 sec)
# INFO:tensorflow:global_step/sec: 23.6793
# INFO:tensorflow:loss = 0.013482755, step = 17392 (4.223 sec)
# INFO:tensorflow:global_step/sec: 23.7308
# INFO:tensorflow:loss = 0.020724561, step = 17492 (4.216 sec)
# INFO:tensorflow:global_step/sec: 23.7445
# INFO:tensorflow:loss = 0.0038038862, step = 17592 (4.210 sec)
# INFO:tensorflow:global_step/sec: 23.8115
# INFO:tensorflow:loss = 0.018541588, step = 17692 (4.201 sec)
# INFO:tensorflow:Saving checkpoints for 17725 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.012168679.
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-02-03:20:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-17725
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-02-03:20:30
# INFO:tensorflow:Saving dict for global step 17725: Accuracy = 0.99298763, Precision = 0.9997412, Recall = 0.99975413, global_step = 17725, loss = 0.024106858
# Epoch 9
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-17725
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 17726 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:loss = 0.017577533, step = 17725
# INFO:tensorflow:global_step/sec: 21.9173
# INFO:tensorflow:loss = 0.009242476, step = 17825 (4.564 sec)
# INFO:tensorflow:global_step/sec: 23.8638
# INFO:tensorflow:loss = 0.0078122914, step = 17925 (4.190 sec)
# INFO:tensorflow:global_step/sec: 23.8259
# INFO:tensorflow:loss = 0.015284242, step = 18025 (4.197 sec)
# INFO:tensorflow:global_step/sec: 23.8296
# INFO:tensorflow:loss = 0.010981702, step = 18125 (4.196 sec)
# INFO:tensorflow:global_step/sec: 23.8309
# INFO:tensorflow:loss = 0.014101731, step = 18225 (4.197 sec)
# INFO:tensorflow:global_step/sec: 23.8791
# INFO:tensorflow:loss = 0.015582095, step = 18325 (4.187 sec)
# INFO:tensorflow:Saving checkpoints for 18358 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.003063921.
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-02-03:20:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-18358
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-02-03:21:06
# INFO:tensorflow:Saving dict for global step 18358: Accuracy = 0.99437034, Precision = 0.99962485, Recall = 0.99984473, global_step = 18358, loss = 0.018520944
# Epoch 10
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-18358
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 18359 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:loss = 0.004847143, step = 18358
# INFO:tensorflow:global_step/sec: 22.3704
# INFO:tensorflow:loss = 0.013078093, step = 18458 (4.472 sec)
# INFO:tensorflow:global_step/sec: 23.8245
# INFO:tensorflow:loss = 0.0017906423, step = 18558 (4.197 sec)
# INFO:tensorflow:global_step/sec: 23.6683
# INFO:tensorflow:loss = 0.010719039, step = 18658 (4.225 sec)
# INFO:tensorflow:global_step/sec: 23.686
# INFO:tensorflow:loss = 0.01234362, step = 18758 (4.222 sec)
# INFO:tensorflow:global_step/sec: 23.7007
# INFO:tensorflow:loss = 0.0040332004, step = 18858 (4.219 sec)
# INFO:tensorflow:global_step/sec: 23.7
# INFO:tensorflow:loss = 0.029884882, step = 18958 (4.219 sec)
# INFO:tensorflow:Saving checkpoints for 18991 into /home/worker3/projects/deepsat6/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.010049879.
# INFO:tensorflow:Calling model_fn.
# Shape Conv1:(?, 28, 28, 32)
# Shape Pool1:(?, 14, 14, 32)
# Shape Conv2:(?, 14, 14, 64)
# Shape Pool2:(?, 7, 7, 64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-02-03:21:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/worker3/projects/deepsat6/model/model.ckpt-18991
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-02-03:21:41
# INFO:tensorflow:Saving dict for global step 18991: Accuracy = 0.9938025, Precision = 0.9999482, Recall = 0.9992495, global_step = 18991, loss = 0.022717584
